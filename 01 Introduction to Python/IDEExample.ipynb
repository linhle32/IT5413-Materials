# %%
import numpy as np
# %matplotlib notebook
from matplotlib import pyplot as plt

# %%
X = np.random.normal(0,1,20)

# %%
print(X)
# Out:
# [ 0.70567724  0.23054965  0.85003542  0.67015071  0.17703209  0.0274826
#   0.03207708  0.84421808  0.42557664  0.16038849  0.32986745 -1.36988396
#  -0.47043987  0.62198139  0.58689745 -0.80090498  0.43921242 -0.13959275
#  -0.75645498 -0.1945991 ]

# %%
plt.plot(X)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="488">
